# %% [markdown]
# <a href="https://colab.research.google.com/github/vitoria-raupp/VisualizacaoDados/blob/main/Teste_Projeto_inep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
d2013 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2013.csv', encoding='latin1', sep=';')
# Out:
# <ipython-input-30-edeedcb33187>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2013 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2013.csv', encoding='latin1', sep=';')

# %%
colunas_s = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR','QT_COMPUTADOR','QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO','QT_COMP_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA', 'IN_EQUIP_LOUSA_DIGITAL', 'QT_EQUIP_LOUSA_DIGITAL']
d2013s = d2013[colunas_s]
print(d2013s.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242680 entries, 0 to 242679
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       242680 non-null  object
#  1   NO_UF                           242680 non-null  object
#  2   SG_UF                           242680 non-null  object
#  3   CO_ENTIDADE                     242680 non-null  int64
#  4   NO_ENTIDADE                     242680 non-null  object
#  5   TP_DEPENDENCIA                  242680 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     242680 non-null  int64
#  7   TP_LOCALIZACAO                  242680 non-null  int64
#  8   TP_LOCALIZACAO_DIFERENCIADA     242680 non-null  int64
#  9   NU_ANO_CENSO                    242680 non-null  int64
#  10  IN_ENERGIA_INEXISTENTE          242680 non-null  int64
#  11  IN_LABORATORIO_INFORMATICA      242680 non-null  int64
# ...

# %%
for coluna in ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR','QT_COMPUTADOR', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO','QT_COMP_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA', 'IN_EQUIP_LOUSA_DIGITAL']: #"'QT_EQUIP_LOUSA_DIGITAL'"
    print(f"Contagem de valores na coluna {coluna}:")
    print(d2013s[coluna].value_counts())
# Out:
# Contagem de valores na coluna NO_REGIAO:
# NO_REGIAO
# Nordeste        95855
# Sudeste         76129
# Sul             29914
# Norte           29297
# Centro-Oeste    11485
# Name: count, dtype: int64
# Contagem de valores na coluna NO_UF:
# NO_UF
# São Paulo              31518
# Minas Gerais           26630
# Bahia                  26205
# Maranhão               15610
# Pará                   14029
# Rio de Janeiro         13575
# Pernambuco             12721
# Ceará                  12554
# Rio Grande do Sul      12040
# Paraná                 10313
# Piauí                   8680
# Paraíba                 7786
# Santa Catarina          7561
# Amazonas                6696
# Rio Grande do Norte     5634
# Goiás                   5335
# Espírito Santo          4406
# Alagoas                 3867
# Mato Grosso             3215
# Tocantins               2896
# Sergipe                 2798
# Acre                    2049
# Rondônia                1848
# Mato Grosso do Sul      1717
# ...

# %%
d2013s.head()
# Out:
#   NO_REGIAO     NO_UF SG_UF  CO_ENTIDADE                 NO_ENTIDADE  \
# 0     Norte  Rondônia    RO     11022558       EIEEF HAP BITT TUPARI
# 1     Norte  Rondônia    RO     11024275    CEEJA LUIZ VAZ DE CAMOES
# 2     Norte  Rondônia    RO     11024291        EMMEF 07 DE SETEMBRO
# 3     Norte  Rondônia    RO     11024313  EMMEF AFONSO AURELIO PORTO
# 4     Norte  Rondônia    RO     11024348    EMMEF ALUISIO DE AZEVEDO
#
#    TP_DEPENDENCIA  TP_CATEGORIA_ESCOLA_PRIVADA  TP_LOCALIZACAO  \
# 0               2                            0               2
# 1               2                            0               1
# 2               3                            0               2
# 3               3                            0               2
# 4               3                            0               2
#
#    TP_LOCALIZACAO_DIFERENCIADA  NU_ANO_CENSO  ...  IN_TABLET_ALUNO  \
# 0                            2          2013  ...                0
# ...

# %%
d2013s.columns
# Out:
# Index(['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE',
#        'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO',
#        'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE',
#        'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL',
#        'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO',
#        'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO',
#        'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET',
#        'IN_INTERNET_ALUNOS', 'IN_INTERNET_ADMINISTRATIVO',
#        'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR',
#        'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA'],
#       dtype='object')

# %%
print(d2013s.isnull().sum())
# Out:
# NO_REGIAO                         0
# NO_UF                             0
# SG_UF                             0
# CO_ENTIDADE                       0
# NO_ENTIDADE                       0
# TP_DEPENDENCIA                    0
# TP_CATEGORIA_ESCOLA_PRIVADA       0
# TP_LOCALIZACAO                    0
# TP_LOCALIZACAO_DIFERENCIADA       0
# NU_ANO_CENSO                      0
# IN_ENERGIA_INEXISTENTE            0
# IN_LABORATORIO_INFORMATICA        0
# IN_COMPUTADOR                     0
# QT_EQUIP_LOUSA_DIGITAL            0
# IN_EQUIP_MULTIMIDIA               0
# QT_EQUIP_MULTIMIDIA               0
# IN_DESKTOP_ALUNO                  0
# QT_DESKTOP_ALUNO                  0
# IN_COMP_PORTATIL_ALUNO            0
# QT_COMP_PORTATIL_ALUNO            0
# IN_TABLET_ALUNO                   0
# QT_TABLET_ALUNO                   0
# IN_INTERNET                       0
# IN_INTERNET_ALUNOS                0
# IN_INTERNET_ADMINISTRATIVO        0
# IN_INTERNET_APRENDIZAGEM          0
# ...

# %%
print(d2013s.describe())
# Out:
#         CO_ENTIDADE  TP_DEPENDENCIA  TP_CATEGORIA_ESCOLA_PRIVADA  \
# count  2.426800e+05   242680.000000                242680.000000
# mean   2.981646e+07        3.057673                     0.265077
# std    9.317643e+06        0.594884                     0.763326
# min    1.100002e+07        1.000000                     0.000000
# 25%    2.316582e+07        3.000000                     0.000000
# 50%    2.942184e+07        3.000000                     0.000000
# 75%    3.517840e+07        3.000000                     0.000000
# max    5.308803e+07        4.000000                     4.000000
#
#        TP_LOCALIZACAO  TP_LOCALIZACAO_DIFERENCIADA  NU_ANO_CENSO  \
# count   242680.000000                242680.000000      242680.0
# mean         1.434222                     0.078960        2013.0
# std          0.495655                     0.430659           0.0
# min          1.000000                     0.000000        2013.0
# ...

# %%
d2014 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2014.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2014s = d2014[colunas_selecionadas]
print(d2014s.info())
# Out:
# <ipython-input-19-2ad1f677eb09>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2014 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2014.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242929 entries, 0 to 242928
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       242929 non-null  object
#  1   NO_UF                           242929 non-null  object
#  2   SG_UF                           242929 non-null  object
#  3   CO_ENTIDADE                     242929 non-null  int64
#  4   NO_ENTIDADE                     242929 non-null  object
#  5   TP_DEPENDENCIA                  242929 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     242929 non-null  int64
#  7   TP_LOCALIZACAO                  242929 non-null  int64
# ...

# %%
for coluna1 in ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']:
    print(f"Contagem de valores na coluna {coluna1}:")
    print(d2014s[coluna1].value_counts())
# Out:
# Contagem de valores na coluna NO_REGIAO:
# NO_REGIAO
# Nordeste        95423
# Sudeste         76643
# Sul             30166
# Norte           29146
# Centro-Oeste    11551
# Name: count, dtype: int64
# Contagem de valores na coluna NO_UF:
# NO_UF
# São Paulo              31962
# Minas Gerais           26611
# Bahia                  26295
# Maranhão               15667
# Pará                   13929
# Rio de Janeiro         13719
# Pernambuco             12622
# Ceará                  12494
# Rio Grande do Sul      12110
# Paraná                 10345
# Piauí                   8593
# Santa Catarina          7711
# Paraíba                 7426
# Amazonas                6755
# Rio Grande do Norte     5688
# Goiás                   5331
# Espírito Santo          4351
# Alagoas                 3787
# Mato Grosso             3205
# Tocantins               2891
# Sergipe                 2851
# Acre                    1995
# Rondônia                1782
# Mato Grosso do Sul      1768
# ...

# %%
d2015 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2015.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2015s = d2015[colunas_selecionadas]
print(d2015s.info())
# Out:
# <ipython-input-21-3154ac06b976>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2015 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2015.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237879 entries, 0 to 237878
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       237879 non-null  object
#  1   NO_UF                           237879 non-null  object
#  2   SG_UF                           237879 non-null  object
#  3   CO_ENTIDADE                     237879 non-null  int64
#  4   NO_ENTIDADE                     237879 non-null  object
#  5   TP_DEPENDENCIA                  237879 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     237879 non-null  int64
#  7   TP_LOCALIZACAO                  237879 non-null  int64
# ...

# %%
for coluna2 in ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']:
    print(f"Contagem de valores na coluna {coluna2}:")
    print(d2015s[coluna2].value_counts())
# Out:
# Contagem de valores na coluna NO_REGIAO:
# NO_REGIAO
# Nordeste        91659
# Sudeste         76650
# Sul             29932
# Norte           28253
# Centro-Oeste    11385
# Name: count, dtype: int64
# Contagem de valores na coluna NO_UF:
# NO_UF
# São Paulo              32446
# Minas Gerais           26095
# Bahia                  24522
# Maranhão               15445
# Rio de Janeiro         13767
# Pará                   13634
# Ceará                  12460
# Pernambuco             12020
# Rio Grande do Sul      12009
# Paraná                 10190
# Piauí                   7944
# Santa Catarina          7733
# Paraíba                 7135
# Amazonas                6438
# Rio Grande do Norte     5602
# Goiás                   5075
# Espírito Santo          4342
# Alagoas                 3711
# Mato Grosso             3207
# Tocantins               2882
# Sergipe                 2820
# Acre                    1955
# Mato Grosso do Sul      1813
# Rondônia                1589
# ...

# %%
d2016 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2016.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2016s = d2016[colunas_selecionadas]
d2016s.to_csv('censo_escolar_selecionado.csv', index=False)
print(d2016s.info())
# Out:
# <ipython-input-23-5824f8fa0d4a>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2016 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2016.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237506 entries, 0 to 237505
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       237506 non-null  object
#  1   NO_UF                           237506 non-null  object
#  2   SG_UF                           237506 non-null  object
#  3   CO_ENTIDADE                     237506 non-null  int64
#  4   NO_ENTIDADE                     237506 non-null  object
#  5   TP_DEPENDENCIA                  237506 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     237506 non-null  int64
#  7   TP_LOCALIZACAO                  237506 non-null  int64
# ...

# %%
for coluna3 in ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']:
    print(f"Contagem de valores na coluna {coluna3}:")
    print(d2016s[coluna3].value_counts())
# Out:
# Contagem de valores na coluna NO_REGIAO:
# NO_REGIAO
# Nordeste        92260
# Sudeste         75892
# Sul             29820
# Norte           27805
# Centro-Oeste    11729
# Name: count, dtype: int64
# Contagem de valores na coluna NO_UF:
# NO_UF
# São Paulo              32437
# Bahia                  25701
# Minas Gerais           25589
# Maranhão               14934
# Rio de Janeiro         13559
# Pará                   13369
# Ceará                  12256
# Pernambuco             12234
# Rio Grande do Sul      11920
# Paraná                 10178
# Piauí                   8054
# Santa Catarina          7722
# Paraíba                 7019
# Amazonas                6372
# Rio Grande do Norte     5566
# Goiás                   5359
# Espírito Santo          4307
# Alagoas                 3698
# Mato Grosso             3231
# Tocantins               2845
# Sergipe                 2798
# Acre                    1852
# Mato Grosso do Sul      1836
# Rondônia                1608
# ...

# %%
d2017 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2017.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2017s = d2017[colunas_selecionadas]
print(d2017s.info())
# Out:
# <ipython-input-11-31485fa81997>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2017 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2017.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236481 entries, 0 to 236480
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       236481 non-null  object
#  1   NO_UF                           236481 non-null  object
#  2   SG_UF                           236481 non-null  object
#  3   CO_ENTIDADE                     236481 non-null  int64
#  4   NO_ENTIDADE                     236481 non-null  object
#  5   TP_DEPENDENCIA                  236481 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     236481 non-null  int64
#  7   TP_LOCALIZACAO                  236481 non-null  int64
# ...

# %%
d2018 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2018.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2018s = d2018[colunas_selecionadas]
print(d2018s.info())
# Out:
# <ipython-input-12-70a280ff1bc7>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2018 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2018.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236460 entries, 0 to 236459
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       236460 non-null  object
#  1   NO_UF                           236460 non-null  object
#  2   SG_UF                           236460 non-null  object
#  3   CO_ENTIDADE                     236460 non-null  int64
#  4   NO_ENTIDADE                     236460 non-null  object
#  5   TP_DEPENDENCIA                  236460 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     236460 non-null  int64
#  7   TP_LOCALIZACAO                  236460 non-null  int64
# ...

# %%
d2019 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2019.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2019s = d2019[colunas_selecionadas]
print(d2019s.info())
# Out:
# <ipython-input-13-b3b70d38ec3d>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2019 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2019.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228521 entries, 0 to 228520
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       228521 non-null  object
#  1   NO_UF                           228521 non-null  object
#  2   SG_UF                           228521 non-null  object
#  3   CO_ENTIDADE                     228521 non-null  int64
#  4   NO_ENTIDADE                     228521 non-null  object
#  5   TP_DEPENDENCIA                  228521 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     228521 non-null  int64
#  7   TP_LOCALIZACAO                  228521 non-null  int64
# ...

# %%
d2020 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2020.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2020s = d2020[colunas_selecionadas]
print(d2020s.info())
# Out:
# <ipython-input-14-e7c9c36489dd>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2020 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2020.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224229 entries, 0 to 224228
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       224229 non-null  object
#  1   NO_UF                           224229 non-null  object
#  2   SG_UF                           224229 non-null  object
#  3   CO_ENTIDADE                     224229 non-null  int64
#  4   NO_ENTIDADE                     224229 non-null  object
#  5   TP_DEPENDENCIA                  224229 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     224229 non-null  int64
#  7   TP_LOCALIZACAO                  224229 non-null  int64
# ...

# %%
d2021 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2021.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2021s = d2021[colunas_selecionadas]
print(d2021s.info())
# Out:
# <ipython-input-15-fc458a993cf0>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2021 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2021.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221140 entries, 0 to 221139
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       221140 non-null  object
#  1   NO_UF                           221140 non-null  object
#  2   SG_UF                           221140 non-null  object
#  3   CO_ENTIDADE                     221140 non-null  int64
#  4   NO_ENTIDADE                     221140 non-null  object
#  5   TP_DEPENDENCIA                  221140 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     221140 non-null  int64
#  7   TP_LOCALIZACAO                  221140 non-null  int64
# ...

# %%
d2022 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2022.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2022s = d2022[colunas_selecionadas]
print(d2022s.info())
# Out:
# <ipython-input-16-c27709a62cea>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2022 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2022.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224649 entries, 0 to 224648
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       224649 non-null  object
#  1   NO_UF                           224649 non-null  object
#  2   SG_UF                           224649 non-null  object
#  3   CO_ENTIDADE                     224649 non-null  int64
#  4   NO_ENTIDADE                     224649 non-null  object
#  5   TP_DEPENDENCIA                  224649 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     41759 non-null   float64
#  7   TP_LOCALIZACAO                  224649 non-null  int64
# ...

# %%
d2023 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2023.csv', encoding='latin1', sep=';')
colunas_selecionadas = ['NO_REGIAO', 'NO_UF', 'SG_UF', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'NU_ANO_CENSO', 'IN_ENERGIA_INEXISTENTE', 'IN_LABORATORIO_INFORMATICA', 'IN_COMPUTADOR', 'QT_EQUIP_LOUSA_DIGITAL', 'IN_EQUIP_MULTIMIDIA', 'QT_EQUIP_MULTIMIDIA', 'IN_DESKTOP_ALUNO', 'QT_DESKTOP_ALUNO', 'IN_COMP_PORTATIL_ALUNO', 'QT_COMP_PORTATIL_ALUNO', 'IN_TABLET_ALUNO', 'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS','IN_INTERNET_ADMINISTRATIVO', 'IN_INTERNET_APRENDIZAGEM', 'IN_ACESSO_INTERNET_COMPUTADOR', 'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA']
d2023s = d2023[colunas_selecionadas]
print(d2023s.info())
# Out:
# <ipython-input-17-5a7f47acb7ea>:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2023 = pd.read_csv('/content/drive/My Drive/microdados/microdados_2023.csv', encoding='latin1', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217625 entries, 0 to 217624
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NO_REGIAO                       217625 non-null  object
#  1   NO_UF                           217625 non-null  object
#  2   SG_UF                           217625 non-null  object
#  3   CO_ENTIDADE                     217625 non-null  int64
#  4   NO_ENTIDADE                     217625 non-null  object
#  5   TP_DEPENDENCIA                  217625 non-null  int64
#  6   TP_CATEGORIA_ESCOLA_PRIVADA     42316 non-null   float64
#  7   TP_LOCALIZACAO                  217625 non-null  int64
# ...

# %%
print(d2014s.isnull().sum())
# Out:
# NO_REGIAO                         0
# NO_UF                             0
# SG_UF                             0
# CO_ENTIDADE                       0
# NO_ENTIDADE                       0
# TP_DEPENDENCIA                    0
# TP_CATEGORIA_ESCOLA_PRIVADA       0
# TP_LOCALIZACAO                    0
# TP_LOCALIZACAO_DIFERENCIADA       0
# NU_ANO_CENSO                      0
# IN_ENERGIA_INEXISTENTE            0
# IN_LABORATORIO_INFORMATICA        0
# IN_COMPUTADOR                     0
# QT_EQUIP_LOUSA_DIGITAL            0
# IN_EQUIP_MULTIMIDIA               0
# QT_EQUIP_MULTIMIDIA               0
# IN_DESKTOP_ALUNO                  0
# QT_DESKTOP_ALUNO                  0
# IN_COMP_PORTATIL_ALUNO            0
# QT_COMP_PORTATIL_ALUNO            0
# IN_TABLET_ALUNO                   0
# QT_TABLET_ALUNO                   0
# IN_INTERNET                       0
# IN_INTERNET_ALUNOS                0
# IN_INTERNET_ADMINISTRATIVO        0
# IN_INTERNET_APRENDIZAGEM          0
# ...

# %%
print(d2015s.isnull().sum())
# Out:
# NO_REGIAO                         0
# NO_UF                             0
# SG_UF                             0
# CO_ENTIDADE                       0
# NO_ENTIDADE                       0
# TP_DEPENDENCIA                    0
# TP_CATEGORIA_ESCOLA_PRIVADA       0
# TP_LOCALIZACAO                    0
# TP_LOCALIZACAO_DIFERENCIADA       0
# NU_ANO_CENSO                      0
# IN_ENERGIA_INEXISTENTE            0
# IN_LABORATORIO_INFORMATICA        0
# IN_COMPUTADOR                     0
# QT_EQUIP_LOUSA_DIGITAL            0
# IN_EQUIP_MULTIMIDIA               0
# QT_EQUIP_MULTIMIDIA               0
# IN_DESKTOP_ALUNO                  0
# QT_DESKTOP_ALUNO                  0
# IN_COMP_PORTATIL_ALUNO            0
# QT_COMP_PORTATIL_ALUNO            0
# IN_TABLET_ALUNO                   0
# QT_TABLET_ALUNO                   0
# IN_INTERNET                       0
# IN_INTERNET_ALUNOS                0
# IN_INTERNET_ADMINISTRATIVO        0
# IN_INTERNET_APRENDIZAGEM          0
# ...

# %%
print(d2016s.isnull().sum())
# Out:
# NO_REGIAO                         0
# NO_UF                             0
# SG_UF                             0
# CO_ENTIDADE                       0
# NO_ENTIDADE                       0
# TP_DEPENDENCIA                    0
# TP_CATEGORIA_ESCOLA_PRIVADA       0
# TP_LOCALIZACAO                    0
# TP_LOCALIZACAO_DIFERENCIADA       0
# NU_ANO_CENSO                      0
# IN_ENERGIA_INEXISTENTE            0
# IN_LABORATORIO_INFORMATICA        0
# IN_COMPUTADOR                     0
# QT_EQUIP_LOUSA_DIGITAL            0
# IN_EQUIP_MULTIMIDIA               0
# QT_EQUIP_MULTIMIDIA               0
# IN_DESKTOP_ALUNO                  0
# QT_DESKTOP_ALUNO                  0
# IN_COMP_PORTATIL_ALUNO            0
# QT_COMP_PORTATIL_ALUNO            0
# IN_TABLET_ALUNO                   0
# QT_TABLET_ALUNO                   0
# IN_INTERNET                       0
# IN_INTERNET_ALUNOS                0
# IN_INTERNET_ADMINISTRATIVO        0
# IN_INTERNET_APRENDIZAGEM          0
# ...

# %%
print(d2017s.isnull())
# Out:
#         NO_REGIAO  NO_UF  SG_UF  CO_ENTIDADE  NO_ENTIDADE  TP_DEPENDENCIA  \
# 0           False  False  False        False        False           False
# 1           False  False  False        False        False           False
# 2           False  False  False        False        False           False
# 3           False  False  False        False        False           False
# 4           False  False  False        False        False           False
# ...           ...    ...    ...          ...          ...             ...
# 236476      False  False  False        False        False           False
# 236477      False  False  False        False        False           False
# 236478      False  False  False        False        False           False
# 236479      False  False  False        False        False           False
# 236480      False  False  False        False        False           False
#
#         TP_CATEGORIA_ESCOLA_PRIVADA  TP_LOCALIZACAO  \
# ...
